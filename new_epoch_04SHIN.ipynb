# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/capstone/few-shot-gan-adaptation-main
# Out:
# /content/drive/My Drive/capstone/few-shot-gan-adaptation-main

# %%
# !ls
# Out:
# checkpoints	 LICENSE.txt	  processed_data    samples
# dataset.py	 model.py	  __pycache__	    test_sample
# distributed.py	 noise.pt	  raw_data	    train.py
# feat_cluster.py  non_leaking.py   README.md	    traversal_gif.py
# generate.py	 op		  requirements.txt  viz.py
# imgs		 prepare_data.py  run.sh

# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 9.8MB/s
# ...
#      |████████████████████████████████| 776.8MB 22kB/s
# ...
#      |████████████████████████████████| 12.7MB 268kB/s
# ...
#      |████████████████████████████████| 71kB 8.3MB/s
# ...
#      |████████████████████████████████| 61kB 8.1MB/s
# ...
#      |████████████████████████████████| 2.2MB 28.0MB/s
# ...
#      |████████████████████████████████| 71kB 8.6MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp37-none-any.whl size=655251 sha256=08ca463514c38be280e70edd63a9a7deff611f540124d34abce9dce356e863a3
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.1.1-cp37-none-any.whl size=10188 sha256=6edbf5e131c5484a36d26acf7e80171dd5b195e3e093c32659834ef407647926
#   Stored in directory: /root/.cache/pip/wheels/b8/93/92/a6a8add9047b97dcb2470d2d1642450e6b76b5988e9744e3f0
# ...

# %%
# !nvidia-smi
# Out:
# Tue Jun  8 02:43:21 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch

print("Torch version:{}".format(torch.__version__))
print("cuda version: {}".format(torch.version.cuda))
print("cudnn version:{}".format(torch.backends.cudnn.version()))
# Out:
# Torch version:1.7.0
# cuda version: 10.2
# cudnn version:7605

# %%
pip install Ninja
# Out:
# ...
#      |████████████████████████████████| 112kB 11.9MB/s
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python generate.py --ckpt_target ./checkpoints/ffhq_caricatures.pt --load_noise noise.pt

# %%
# !python prepare_data.py --out processed_data/shinyoonbok --size 256 ./raw_data/shinyoonbok
# Out:
# Make dataset of image sizes: 256
# 10it [00:00, 84.98it/s]

# %%
# !CUDA_VISIBLE_DEVICES=0 python train.py --ckpt ./checkpoints/source_ffhq.pt --data_path ./processed_data/shinyoonbok --exp ffhq_to_shinyoonbok
# Out:
# load model: ./checkpoints/source_ffhq.pt
#   0% 0/5002 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2398: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn("reduction: 'mean' divides the total loss by both the batch size and the support size."
# d: 0.7668; g: 1.3176; r1: 0.0055; path: 0.0008; mean path: 0.1769; augment: 0.0000: 100% 5002/5002 [1:39:11<00:00,  1.19s/it]

# %%
# !CUDA_VISIBLE_DEVICES=0 python generate.py --ckpt_target ./checkpoints/ffhq_to_shinyoonbok/005000.pt --load_noise noise.pt
