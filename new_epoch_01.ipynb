# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/capstone/few-shot-gan-adaptation-main
# Out:
# /content/drive/My Drive/capstone/few-shot-gan-adaptation-main

# %%
# !ls
# Out:
# dataset.py	 LICENSE.txt	 prepare_data.py   test_sample
# distributed.py	 model.py	 __pycache__	   train.py
# feat_cluster.py  noise.pt	 README.md	   traversal_gif.py
# generate.py	 non_leaking.py  requirements.txt  Untitled0.ipynb
# imgs		 op		 run.sh		   viz.py

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: visdom==0.1.8.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.1.8.9)
# Requirement already satisfied: torch==1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: torchvision==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: tqdm==4.51.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: lpips==0.1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (0.1.3)
# Requirement already satisfied: Pillow==8.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (8.0.1)
# Requirement already satisfied: pytorch-fid==0.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (22.0.3)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (1.32)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from visdom==0.1.8.9->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r requirements.txt (line 2)) (0.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->visdom==0.1.8.9->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->visdom==0.1.8.9->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->visdom==0.1.8.9->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->visdom==0.1.8.9->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.7/dist-packages (from jsonpatch->visdom==0.1.8.9->-r requirements.txt (line 1)) (2.1)
# ERROR: Operation cancelled by user

# %%
# !nvidia-smi
# Out:
# Fri May 28 11:47:19 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

print("Torch version:{}".format(torch.__version__))
print("cuda version: {}".format(torch.version.cuda))
print("cudnn version:{}".format(torch.backends.cudnn.version()))
# Out:
# Torch version:1.7.0
# cuda version: 10.2
# cudnn version:7605

# %%
pip install Ninja
# Out:
# Collecting Ninja
#   Downloading https://files.pythonhosted.org/packages/1d/de/393468f2a37fc2c1dc3a06afc37775e27fde2d16845424141d4da62c686d/ninja-1.10.0.post2-py3-none-manylinux1_x86_64.whl (107kB)
#      |████████████████████████████████| 112kB 28.7MB/s
# Installing collected packages: Ninja
# Successfully installed Ninja-1.10.0.post2

# %%
# !CUDA_VISIBLE_DEVICES=0 python generate.py --ckpt_target ./checkpoints/ffhq_sketches.pt --load_noise noise.pt
